# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Files to load
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# %%
# Read the city data file and store it in a pandas DataFrame.
city_data_df = pd.read_csv(city_data_to_load)
city_data_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2437428395.py in <module>
#       1 # Read the city data file and store it in a pandas DataFrame.
# ----> 2 city_data_df = pd.read_csv(city_data_to_load)
#       3 city_data_df.head(10)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Resources/city_data.csv'

# %%
# Read the ride data file and store it in a pandas DataFrame.
ride_data_df = pd.read_csv(ride_data_to_load)
ride_data_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2087134196.py in <module>
#       1 # Read the ride data file and store it in a pandas DataFrame.
# ----> 2 ride_data_df = pd.read_csv(ride_data_to_load)
#       3 ride_data_df.head(10)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Resources/ride_data.csv'

# %%
# Get the columns and the rows that are not null.
city_data_df.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/275880087.py in <module>
#       1 # Get the columns and the rows that are not null.
# ----> 2 city_data_df.count()
#
# NameError: name 'city_data_df' is not defined

# %%
# Get the columns and the rows that are not null.
city_data_df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/1365619218.py in <module>
#       1 # Get the columns and the rows that are not null.
# ----> 2 city_data_df.isnull().sum()
#
# NameError: name 'city_data_df' is not defined

# %%
# Get the data types of each column.
city_data_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/4108536971.py in <module>
#       1 # Get the data types of each column.
# ----> 2 city_data_df.dtypes
#
# NameError: name 'city_data_df' is not defined

# %%
# Get the unique values of the type of city.
city_data_df["type"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/3366811613.py in <module>
#       1 # Get the unique values of the type of city.
# ----> 2 city_data_df["type"].unique()
#
# NameError: name 'city_data_df' is not defined

# %%
# Get the number of data points from the Urban cities.
sum(city_data_df["type"]=="Urban")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/543587067.py in <module>
#       1 # Get the number of data points from the Urban cities.
# ----> 2 sum(city_data_df["type"]=="Urban")
#
# NameError: name 'city_data_df' is not defined

# %%
sum(ride_data_df["fare"]>=30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/1849394149.py in <module>
# ----> 1 sum(ride_data_df["fare"]>=30)
#
# NameError: name 'ride_data_df' is not defined

# %%
sum(city_data_df["type"]=="Suburban")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/3697007285.py in <module>
# ----> 1 sum(city_data_df["type"]=="Suburban")
#
# NameError: name 'city_data_df' is not defined

# %%
sum(city_data_df["type"]=="Rural")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/894020081.py in <module>
# ----> 1 sum(city_data_df["type"]=="Rural")
#
# NameError: name 'city_data_df' is not defined

# %%
# Get the columns and the rows that are not null.
ride_data_df.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/3977933330.py in <module>
#       1 # Get the columns and the rows that are not null.
# ----> 2 ride_data_df.count()
#
# NameError: name 'ride_data_df' is not defined

# %%
# Get the data types of each column.
ride_data_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2747017256.py in <module>
#       1 # Get the data types of each column.
# ----> 2 ride_data_df.dtypes
#
# NameError: name 'ride_data_df' is not defined

# %%
new_df = pd.merge(leftdf, rightdf, on=["column_leftdf", "column_rightdf"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/3819505948.py in <module>
# ----> 1 new_df = pd.merge(leftdf, rightdf, on=["column_leftdf", "column_rightdf"])
#
# NameError: name 'leftdf' is not defined

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the DataFrame
pyber_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/109632515.py in <module>
#       1 # Combine the data into a single dataset
# ----> 2 pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])
#       3
#       4 # Display the DataFrame
#       5 pyber_data_df.head()
#
# NameError: name 'ride_data_df' is not defined

# %%
# Create the Urban city DataFrame.
urban_cities_df = pyber_data_df[pyber_data_df["type"] == "Urban"]
urban_cities_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/1023399686.py in <module>
#       1 # Create the Urban city DataFrame.
# ----> 2 urban_cities_df = pyber_data_df[pyber_data_df["type"] == "Urban"]
#       3 urban_cities_df.head()
#
# NameError: name 'pyber_data_df' is not defined

# %%
# Create the Suburban and Rural city DataFrames.
suburban_cities_df = pyber_data_df[pyber_data_df["type"] == "Suburban"]
rural_cities_df = pyber_data_df[pyber_data_df["type"] == "Rural"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/3788539495.py in <module>
#       1 # Create the Suburban and Rural city DataFrames.
# ----> 2 suburban_cities_df = pyber_data_df[pyber_data_df["type"] == "Suburban"]
#       3 rural_cities_df = pyber_data_df[pyber_data_df["type"] == "Rural"]
#
# NameError: name 'pyber_data_df' is not defined

# %%
# Get the number of rides for urban cities.
urban_ride_count = urban_cities_df.groupby(["city"]).count()["ride_id"]
urban_ride_count.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2447336509.py in <module>
#       1 # Get the number of rides for urban cities.
# ----> 2 urban_ride_count = urban_cities_df.groupby(["city"]).count()["ride_id"]
#       3 urban_ride_count.head()
#
# NameError: name 'urban_cities_df' is not defined

# %%
# Create the suburban and rural ride count.
suburban_ride_count = suburban_cities_df.groupby(["city"]).count()["ride_id"]

rural_ride_count = rural_cities_df.groupby(["city"]).count()["ride_id"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2868816619.py in <module>
#       1 # Create the suburban and rural ride count.
# ----> 2 suburban_ride_count = suburban_cities_df.groupby(["city"]).count()["ride_id"]
#       3
#       4 rural_ride_count = rural_cities_df.groupby(["city"]).count()["ride_id"]
#
# NameError: name 'suburban_cities_df' is not defined

# %%
# Get average fare for each city in the urban cities.
urban_avg_fare = urban_cities_df.groupby(["city"]).mean()["fare"]
urban_avg_fare.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/3642064026.py in <module>
#       1 # Get average fare for each city in the urban cities.
# ----> 2 urban_avg_fare = urban_cities_df.groupby(["city"]).mean()["fare"]
#       3 urban_avg_fare.head()
#
# NameError: name 'urban_cities_df' is not defined

# %%
# Get average fare for each city in the suburban and rural cities.
suburban_avg_fare = suburban_cities_df.groupby(["city"]).mean()["fare"]
rural_avg_fare = rural_cities_df.groupby(["city"]).mean()["fare"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/1651721153.py in <module>
#       1 # Get average fare for each city in the suburban and rural cities.
# ----> 2 suburban_avg_fare = suburban_cities_df.groupby(["city"]).mean()["fare"]
#       3 rural_avg_fare = rural_cities_df.groupby(["city"]).mean()["fare"]
#
# NameError: name 'suburban_cities_df' is not defined

# %%
# Get the average number of drivers for each urban city.
urban_driver_count = urban_cities_df.groupby(["city"]).mean()["driver_count"]
urban_driver_count.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/4072658461.py in <module>
#       1 # Get the average number of drivers for each urban city.
# ----> 2 urban_driver_count = urban_cities_df.groupby(["city"]).mean()["driver_count"]
#       3 urban_driver_count.head()
#
# NameError: name 'urban_cities_df' is not defined

# %%
# Get the average number of drivers for each city for the suburban and rural cities.
suburban_driver_count = suburban_cities_df.groupby(["city"]).mean()["driver_count"]
rural_driver_count = rural_cities_df.groupby(["city"]).mean()["driver_count"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2222322037.py in <module>
#       1 # Get the average number of drivers for each city for the suburban and rural cities.
# ----> 2 suburban_driver_count = suburban_cities_df.groupby(["city"]).mean()["driver_count"]
#       3 rural_driver_count = rural_cities_df.groupby(["city"]).mean()["driver_count"]
#
# NameError: name 'suburban_cities_df' is not defined

# %%
# Build the scatter plots for urban cities.
plt.scatter(urban_ride_count,
      urban_avg_fare,
      s=urban_driver_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/4008600686.py in <module>
#       1 # Build the scatter plots for urban cities.
# ----> 2 plt.scatter(urban_ride_count,
#       3       urban_avg_fare,
#       4       s=urban_driver_count)
#
# NameError: name 'urban_ride_count' is not defined

# %%
# Build the scatter plots for urban cities.
plt.scatter(urban_ride_count,
      urban_avg_fare,
      s=10*urban_driver_count, c="coral",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Urban")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
# Add the legend.
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/3440692075.py in <module>
#       1 # Build the scatter plots for urban cities.
# ----> 2 plt.scatter(urban_ride_count,
#       3       urban_avg_fare,
#       4       s=10*urban_driver_count, c="coral",
#       5       edgecolor="black", linewidths=1,
#
# NameError: name 'urban_ride_count' is not defined

# %%
# Build the scatter plots for suburban cities.
plt.scatter(suburban_ride_count,
      suburban_avg_fare,
      s=10*suburban_driver_count, c="skyblue",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Suburban")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
# Add the legend.
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/1001759914.py in <module>
#       1 # Build the scatter plots for suburban cities.
# ----> 2 plt.scatter(suburban_ride_count,
#       3       suburban_avg_fare,
#       4       s=10*suburban_driver_count, c="skyblue",
#       5       edgecolor="black", linewidths=1,
#
# NameError: name 'suburban_ride_count' is not defined

# %%
# Build the scatter plots for rural cities.
plt.scatter(rural_ride_count,
      rural_avg_fare,
      s=10*rural_driver_count, c="gold",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Rural")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
# Add the legend.
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2549851995.py in <module>
#       1 # Build the scatter plots for rural cities.
# ----> 2 plt.scatter(rural_ride_count,
#       3       rural_avg_fare,
#       4       s=10*rural_driver_count, c="gold",
#       5       edgecolor="black", linewidths=1,
#
# NameError: name 'rural_ride_count' is not defined

# %%
# Add the scatter charts for each type of city.
plt.scatter(urban_ride_count,
      urban_avg_fare,
      s=10*urban_driver_count, c="coral",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Urban")

plt.scatter(suburban_ride_count,
      suburban_avg_fare,
      s=10*suburban_driver_count, c="skyblue",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Suburban")

plt.scatter(rural_ride_count,
      rural_avg_fare,
      s=10*rural_driver_count, c="gold",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Rural")

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2778420596.py in <module>
#       1 # Add the scatter charts for each type of city.
# ----> 2 plt.scatter(urban_ride_count,
#       3       urban_avg_fare,
#       4       s=10*urban_driver_count, c="coral",
#       5       edgecolor="black", linewidths=1,
#
# NameError: name 'urban_ride_count' is not defined

# %%
# Build the scatter charts for each city type.
plt.subplots(figsize=(10, 6))
plt.scatter(urban_ride_count,
      urban_avg_fare,
      s=10*urban_driver_count, c="coral",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Urban")

plt.scatter(suburban_ride_count,
      suburban_avg_fare,
      s=10*suburban_driver_count, c="skyblue",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Suburban")

plt.scatter(rural_ride_count,
      rural_avg_fare,
      s=10*rural_driver_count, c="gold",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Rural")

# Incorporate the other graph properties
plt.title("PyBer Ride-Sharing Data (2019)", fontsize=20)
plt.ylabel("Average Fare ($)", fontsize=12)
plt.xlabel("Total Number of Rides (Per City)", fontsize=12)
plt.grid(True)

# Add the legend.
plt.legend()
# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/1456251469.py in <module>
#       1 # Build the scatter charts for each city type.
#       2 plt.subplots(figsize=(10, 6))
# ----> 3 plt.scatter(urban_ride_count,
#       4       urban_avg_fare,
#       5       s=10*urban_driver_count, c="coral",
#
# NameError: name 'urban_ride_count' is not defined

# %%
# Create a legend
lgnd = plt.legend(fontsize="12", mode="Expanded",
         scatterpoints=1, loc="best", title="City Types")
lgnd.legendHandles[0]._sizes = [75]
lgnd.legendHandles[1]._sizes = [75]
lgnd.legendHandles[2]._sizes = [75]
lgnd.get_title().set_fontsize(12)
# Out:
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2679333525.py in <module>
#       2 lgnd = plt.legend(fontsize="12", mode="Expanded",
#       3          scatterpoints=1, loc="best", title="City Types")
# ----> 4 lgnd.legendHandles[0]._sizes = [75]
#       5 lgnd.legendHandles[1]._sizes = [75]
#       6 lgnd.legendHandles[2]._sizes = [75]
#
# IndexError: list index out of range

# %%
# Incorporate a text label about circle size.
plt.text(42, 35, "Note: Circle size correlates with driver count per city.", fontsize="12")
# Out:
# Text(42, 35, 'Note: Circle size correlates with driver count per city.')

# %%
# Save the figure.
plt.savefig("analysis/Fig1.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2523341393.py in <module>
#       1 # Save the figure.
# ----> 2 plt.savefig("analysis/Fig1.png")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     964 def savefig(*args, **kwargs):
#     965     fig = gcf()
# --> 966     res = fig.savefig(*args, **kwargs)
#     967     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     968     return res
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3013                 patch.set_edgecolor('none')
#    3014
# -> 3015         self.canvas.print_figure(fname, **kwargs)
#    3016
#    3017         if transparent:
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     507         """
#     508         FigureCanvasAgg.draw(self)
# --> 509         mpl.image.imsave(
#     510             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     511             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1614         pil_kwargs.setdefault("format", format)
#    1615         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1616         image.save(fname, **pil_kwargs)
#    1617
#    1618
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2235                 fp = builtins.open(filename, "r+b")
#    2236             else:
# -> 2237                 fp = builtins.open(filename, "w+b")
#    2238
#    2239         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'analysis/Fig1.png'

# %%
# Get summary statistics.
urban_cities_df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/60400584.py in <module>
#       1 # Get summary statistics.
# ----> 2 urban_cities_df.describe()
#
# NameError: name 'urban_cities_df' is not defined

# %%
# Get summary statistics.
urban_ride_count.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2373290825.py in <module>
#       1 # Get summary statistics.
# ----> 2 urban_ride_count.describe()
#
# NameError: name 'urban_ride_count' is not defined

# %%
# Calculate the mean of the ride count for each city type.
round(urban_ride_count.mean(),2), round(suburban_ride_count.mean(),2), round(rural_ride_count.mean(),2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/1932531722.py in <module>
#       1 # Calculate the mean of the ride count for each city type.
# ----> 2 round(urban_ride_count.mean(),2), round(suburban_ride_count.mean(),2), round(rural_ride_count.mean(),2)
#
# NameError: name 'urban_ride_count' is not defined

# %%
# Calculate the mode of the ride count for the urban cities.
urban_ride_count.mode()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/1783329496.py in <module>
#       1 # Calculate the mode of the ride count for the urban cities.
# ----> 2 urban_ride_count.mode()
#
# NameError: name 'urban_ride_count' is not defined

# %%
# Import NumPy and the stats module from SciPy.
import numpy as np
import scipy.stats as sts

# %%
# Calculate the measures of central tendency for the ride count for the urban cities.
mean_urban_ride_count = np.mean(urban_ride_count)
print(f"The mean for the ride counts for urban trips is {mean_urban_ride_count:.2f}.")

median_urban_ride_count = np.median(urban_ride_count)
print(f"The median for the ride counts for urban trips is {median_urban_ride_count}.")

mode_urban_ride_count = sts.mode(urban_ride_count)
print(f"The mode for the ride counts for urban trips is {mode_urban_ride_count}.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/4065532208.py in <module>
#       1 # Calculate the measures of central tendency for the ride count for the urban cities.
# ----> 2 mean_urban_ride_count = np.mean(urban_ride_count)
#       3 print(f"The mean for the ride counts for urban trips is {mean_urban_ride_count:.2f}.")
#       4
#       5 median_urban_ride_count = np.median(urban_ride_count)
#
# NameError: name 'urban_ride_count' is not defined

# %%
# Get the fares for the urban cities.
urban_fares = urban_cities_df["fare"]
urban_fares.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2624714025.py in <module>
#       1 # Get the fares for the urban cities.
# ----> 2 urban_fares = urban_cities_df["fare"]
#       3 urban_fares.head()
#
# NameError: name 'urban_cities_df' is not defined

# %%
# Calculate the measures of central tendency for the average fare for the urban cities.
mean_urban_fares = np.mean(urban_fares)
print(f"The mean fare price for urban trips is ${mean_urban_fares:.2f}.")

median_urban_fares = np.median(urban_fares)
print(f"The median fare price for urban trips is ${median_urban_fares:.2f}.")

mode_urban_fares = sts.mode(urban_fares)
print(f"The mode fare price for urban trips is {mode_urban_fares}.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/244280386.py in <module>
#       1 # Calculate the measures of central tendency for the average fare for the urban cities.
# ----> 2 mean_urban_fares = np.mean(urban_fares)
#       3 print(f"The mean fare price for urban trips is ${mean_urban_fares:.2f}.")
#       4
#       5 median_urban_fares = np.median(urban_fares)
#
# NameError: name 'urban_fares' is not defined

# %%
# Get the driver count data from the urban cities.
urban_drivers = urban_cities_df['driver_count']
urban_drivers.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/3722829083.py in <module>
#       1 # Get the driver count data from the urban cities.
# ----> 2 urban_drivers = urban_cities_df['driver_count']
#       3 urban_drivers.head()
#
# NameError: name 'urban_cities_df' is not defined

# %%
mean_urban_drivers_count = np.mean(urban_drivers)
print(f"The mean for the driver counts for urban trips is {mean_urban_drivers_count:.2f}.")
mean_suburban_drivers_count = np.mean(suburban_drivers)
print(f"The mean for the driver counts for suburban trips is {mean_suburban_drivers_count:.2f}.")
mean_rural_drivers_count = np.mean(rural_drivers)
print(f"The mean for the driver counts for rural trips is {mean_rural_drivers_count:.2f}.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/652705790.py in <module>
# ----> 1 mean_urban_drivers_count = np.mean(urban_drivers)
#       2 print(f"The mean for the driver counts for urban trips is {mean_urban_drivers_count:.2f}.")
#       3 mean_suburban_drivers_count = np.mean(suburban_drivers)
#       4 print(f"The mean for the driver counts for suburban trips is {mean_suburban_drivers_count:.2f}.")
#       5 mean_rural_drivers_count = np.mean(rural_drivers)
#
# NameError: name 'urban_drivers' is not defined

# %%
mean_drivers_array = [mean_urban_drivers_count,mean_suburban_drivers_count,mean_rural_drivers_count]
mean_drivers_array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/4265921173.py in <module>
# ----> 1 mean_drivers_array = [mean_urban_drivers_count,mean_suburban_drivers_count,mean_rural_drivers_count]
#       2 mean_drivers_array
#
# NameError: name 'mean_urban_drivers_count' is not defined

# %%
median_urban_drivers_count = np.median(urban_drivers)
print(f"The median for the driver counts for urban trips is {median_urban_drivers_count:.2f}.")
median_suburban_drivers_count = np.median(suburban_drivers)
print(f"The median for the driver counts for suburban trips is {median_suburban_drivers_count:.2f}.")
median_rural_drivers_count = np.median(rural_drivers)
print(f"The median for the driver counts for rural trips is {median_rural_drivers_count:.2f}.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/253756224.py in <module>
# ----> 1 median_urban_drivers_count = np.median(urban_drivers)
#       2 print(f"The median for the driver counts for urban trips is {median_urban_drivers_count:.2f}.")
#       3 median_suburban_drivers_count = np.median(suburban_drivers)
#       4 print(f"The median for the driver counts for suburban trips is {median_suburban_drivers_count:.2f}.")
#       5 median_rural_drivers_count = np.median(rural_drivers)
#
# NameError: name 'urban_drivers' is not defined

# %%
median_drivers_array = [median_urban_drivers_count,median_suburban_drivers_count,median_rural_drivers_count]
median_drivers_array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2037071851.py in <module>
# ----> 1 median_drivers_array = [median_urban_drivers_count,median_suburban_drivers_count,median_rural_drivers_count]
#       2 median_drivers_array
#
# NameError: name 'median_urban_drivers_count' is not defined

# %%
mode_urban_drivers_count = sts.mode(urban_drivers)
print(f"The mode for the driver counts for urban trips is {mode_urban_drivers_count}.")
mode_suburban_drivers_count = sts.mode(suburban_drivers)
print(f"The mode for the driver counts for suburban trips is {mode_suburban_drivers_count}.")
mode_rural_drivers_count = sts.mode(rural_drivers)
print(f"The mode for the driver counts for rural trips is {mode_rural_drivers_count}.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2622862321.py in <module>
# ----> 1 mode_urban_drivers_count = sts.mode(urban_drivers)
#       2 print(f"The mode for the driver counts for urban trips is {mode_urban_drivers_count}.")
#       3 mode_suburban_drivers_count = sts.mode(suburban_drivers)
#       4 print(f"The mode for the driver counts for suburban trips is {mode_suburban_drivers_count}.")
#       5 mode_rural_drivers_count = sts.mode(rural_drivers)
#
# NameError: name 'urban_drivers' is not defined

# %%
# Create a box-and-whisker plot for the urban cities ride count.
x_labels = ["Urban"]
fig, ax = plt.subplots()
ax.boxplot(urban_ride_count, labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Ride Count Data (2019)')
ax.set_ylabel('Number of Rides')
ax.set_yticks(np.arange(10, 41, step=2.0))
ax.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/4095181289.py in <module>
#       2 x_labels = ["Urban"]
#       3 fig, ax = plt.subplots()
# ----> 4 ax.boxplot(urban_ride_count, labels=x_labels)
#       5 # Add the title, y-axis label and grid.
#       6 ax.set_title('Ride Count Data (2019)')
#
# NameError: name 'urban_ride_count' is not defined

# %%
# Create a box-and-whisker plot for the urban cities ride count.
x_labels = ["Suburban"]
fig, ax = plt.subplots()
ax.boxplot(suburban_ride_count, labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Ride Count Data (2019)')
ax.set_ylabel('Number of Rides')
ax.set_yticks(np.arange(10, 41, step=2.0))
ax.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/3481812959.py in <module>
#       2 x_labels = ["Suburban"]
#       3 fig, ax = plt.subplots()
# ----> 4 ax.boxplot(suburban_ride_count, labels=x_labels)
#       5 # Add the title, y-axis label and grid.
#       6 ax.set_title('Ride Count Data (2019)')
#
# NameError: name 'suburban_ride_count' is not defined

# %%
# Create a box-and-whisker plot for the urban cities ride count.
x_labels = ["Rural"]
fig, ax = plt.subplots()
ax.boxplot(rural_ride_count, labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Ride Count Data (2019)')
ax.set_ylabel('Number of Rides')
ax.set_yticks(np.arange(2, 41, step=2.0))
ax.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2971186470.py in <module>
#       2 x_labels = ["Rural"]
#       3 fig, ax = plt.subplots()
# ----> 4 ax.boxplot(rural_ride_count, labels=x_labels)
#       5 # Add the title, y-axis label and grid.
#       6 ax.set_title('Ride Count Data (2019)')
#
# NameError: name 'rural_ride_count' is not defined

# %%
# Add all ride count box-and-whisker plots to the same graph.
x_labels = ["Urban", "Suburban","Rural"]
ride_count_data = [urban_ride_count, suburban_ride_count, rural_ride_count]
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Ride Count Data (2019)',fontsize=20)
ax.set_ylabel('Number of Rides',fontsize=14)
ax.set_xlabel("City Types",fontsize=14)
ax.boxplot(ride_count_data, labels=x_labels)
ax.set_yticks(np.arange(0, 45, step=3.0))
ax.grid()
# Save the figure.
plt.savefig("analysis/Fig2.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2995480521.py in <module>
#       1 # Add all ride count box-and-whisker plots to the same graph.
#       2 x_labels = ["Urban", "Suburban","Rural"]
# ----> 3 ride_count_data = [urban_ride_count, suburban_ride_count, rural_ride_count]
#       4 fig, ax = plt.subplots(figsize=(10, 6))
#       5 ax.set_title('Ride Count Data (2019)',fontsize=20)
#
# NameError: name 'urban_ride_count' is not defined

# %%
# Get the city that matches 39.
urban_city_outlier = urban_ride_count[urban_ride_count==39].index[0]
print(f"{urban_city_outlier} has the highest rider count.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/471968182.py in <module>
#       1 # Get the city that matches 39.
# ----> 2 urban_city_outlier = urban_ride_count[urban_ride_count==39].index[0]
#       3 print(f"{urban_city_outlier} has the highest rider count.")
#
# NameError: name 'urban_ride_count' is not defined

# %%
# Create a box-and-whisker plot for the urban fare data.
x_labels = ["Urban"]
fig, ax = plt.subplots()
ax.boxplot(urban_fares, labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Ride Fare Data (2019)')
ax.set_ylabel('Fare($USD)')
ax.set_yticks(np.arange(0, 51, step=5.0))
ax.grid()
plt.show()
print("Summary Statistics")
urban_fares.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/987738968.py in <module>
#       2 x_labels = ["Urban"]
#       3 fig, ax = plt.subplots()
# ----> 4 ax.boxplot(urban_fares, labels=x_labels)
#       5 # Add the title, y-axis label and grid.
#       6 ax.set_title('Ride Fare Data (2019)')
#
# NameError: name 'urban_fares' is not defined

# %%
# Create a box-and-whisker plot for the urban fare data.
x_labels = ["Suburban"]
fig, ax = plt.subplots()
ax.boxplot(suburban_fares, labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Ride Fare Data (2019)')
ax.set_ylabel('Fare($USD)')
ax.set_yticks(np.arange(0, 51, step=5.0))
ax.grid()
plt.show()
print("Summary Statistics")
suburban_fares.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/2233438835.py in <module>
#       2 x_labels = ["Suburban"]
#       3 fig, ax = plt.subplots()
# ----> 4 ax.boxplot(suburban_fares, labels=x_labels)
#       5 # Add the title, y-axis label and grid.
#       6 ax.set_title('Ride Fare Data (2019)')
#
# NameError: name 'suburban_fares' is not defined

# %%
# Create a box-and-whisker plot for the urban fare data.
x_labels = ["Rural"]
fig, ax = plt.subplots()
ax.boxplot(rural_fares, labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Ride Fare Data (2019)')
ax.set_ylabel('Fare($USD)')
ax.set_yticks(np.arange(0, 51, step=5.0))
ax.grid()
plt.show()
print("Summary Statistics")
rural_fares.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/1398540025.py in <module>
#       2 x_labels = ["Rural"]
#       3 fig, ax = plt.subplots()
# ----> 4 ax.boxplot(rural_fares, labels=x_labels)
#       5 # Add the title, y-axis label and grid.
#       6 ax.set_title('Ride Fare Data (2019)')
#
# NameError: name 'rural_fares' is not defined

# %%
# Add all ride count box-and-whisker plots to the same graph.
x_labels = ["Urban", "Suburban","Rural"]
ride_fare_array = [urban_fares, suburban_fares, rural_fares]
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Ride Fare Data (2019)',fontsize=20)
ax.set_ylabel('Fares ($USD)',fontsize=14)
ax.set_xlabel("City Types",fontsize=14)
ax.boxplot(ride_fare_array, labels=x_labels)
ax.set_yticks(np.arange(0, 45, step=3.0))
ax.grid()
# Save the figure.
plt.savefig("analysis/Fig3.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/487066499.py in <module>
#       1 # Add all ride count box-and-whisker plots to the same graph.
#       2 x_labels = ["Urban", "Suburban","Rural"]
# ----> 3 ride_fare_array = [urban_fares, suburban_fares, rural_fares]
#       4 fig, ax = plt.subplots(figsize=(10, 6))
#       5 ax.set_title('Ride Fare Data (2019)',fontsize=20)
#
# NameError: name 'urban_fares' is not defined

# %%
# Add all ride count box-and-whisker plots to the same graph.
x_labels = ["Urban", "Suburban","Rural"]
drivers_count_array = [urban_drivers, suburban_drivers, rural_drivers]
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Driver Count (2019)',fontsize=20)
ax.set_ylabel('Number of Drivers',fontsize=14)
ax.set_xlabel("City Types",fontsize=14)
ax.boxplot(drivers_count_array, labels=x_labels)
ax.set_yticks(np.arange(0, 75, step=3.0))
ax.grid()
# Save the figure.
plt.savefig("analysis/Fig4.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/4291419230.py in <module>
#       1 # Add all ride count box-and-whisker plots to the same graph.
#       2 x_labels = ["Urban", "Suburban","Rural"]
# ----> 3 drivers_count_array = [urban_drivers, suburban_drivers, rural_drivers]
#       4 fig, ax = plt.subplots(figsize=(10, 6))
#       5 ax.set_title('Driver Count (2019)',fontsize=20)
#
# NameError: name 'urban_drivers' is not defined

# %%
# Create the box-and-whisker plot for the urban driver count data.
x_labels = ["Urban"]
fig, ax = plt.subplots()
ax.boxplot(urban_drivers,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Driver Count Data (2019)')
ax.set_ylabel('Number of Drivers)')
ax.set_yticks(np.arange(0, 90, step=5.0))
ax.grid()
plt.show()
print("Summary Statistics")
urban_drivers.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/3407650665.py in <module>
#       2 x_labels = ["Urban"]
#       3 fig, ax = plt.subplots()
# ----> 4 ax.boxplot(urban_drivers,labels=x_labels)
#       5 # Add the title, y-axis label and grid.
#       6 ax.set_title('Driver Count Data (2019)')
#
# NameError: name 'urban_drivers' is not defined

# %%
# Get the sum of the fares for each city type.
sum_fares_by_type = pyber_data_df.groupby(["type"]).sum()["fare"]
sum_fares_by_type
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2096/2505217428.py in <module>
#       1 # Get the sum of the fares for each city type.
# ----> 2 sum_fares_by_type = pyber_data_df.groupby(["type"]).sum()["fare"]
#       3 sum_fares_by_type
#
# NameError: name 'pyber_data_df' is not defined

# %%
# Get the sum of all the fares.
total_fares = pyber_data_df["fare"].sum()
total_fares
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2096/3973139335.py in <module>
#       1 # Get the sum of all the fares.
# ----> 2 total_fares = pyber_data_df["fare"].sum()
#       3 total_fares
#
# NameError: name 'pyber_data_df' is not defined

# %%
# Calculate the percentage of fare for each city type.
type_percents = 100 * sum_fares_by_type / total_fares
type_percents
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2096/3866254715.py in <module>
#       1 # Calculate the percentage of fare for each city type.
# ----> 2 type_percents = 100 * sum_fares_by_type / total_fares
#       3 type_percents
#
# NameError: name 'sum_fares_by_type' is not defined

# %%
# Calculate the percentage of fare for each city type.
type_percents = 100 * pyber_data_df.groupby(["type"]).sum()["fare"] / pyber_data_df["fare"].sum()
type_percents
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2096/2610159878.py in <module>
#       1 # Calculate the percentage of fare for each city type.
# ----> 2 type_percents = 100 * pyber_data_df.groupby(["type"]).sum()["fare"] / pyber_data_df["fare"].sum()
#       3 type_percents
#
# NameError: name 'pyber_data_df' is not defined

# %%
# Build the percentage of fares by city type pie chart.
plt.pie(type_percents, labels=["Rural", "Suburban", "Urban"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2096/1951241231.py in <module>
#       1 # Build the percentage of fares by city type pie chart.
# ----> 2 plt.pie(type_percents, labels=["Rural", "Suburban", "Urban"])
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# Build the percentage of fares by city type pie chart.
plt.pie(type_percents,
    labels=["Rural", "Suburban", "Urban"],
    colors=["gold", "lightskyblue", "lightcoral"],
    explode=[0, 0, 0.1],
    autopct='%1.1f%%',
    shadow=True, startangle=150)
plt.title("% of Total Fares by City Type")
# Show Figure
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2096/3432512830.py in <module>
#       1 # Build the percentage of fares by city type pie chart.
# ----> 2 plt.pie(type_percents,
#       3     labels=["Rural", "Suburban", "Urban"],
#       4     colors=["gold", "lightskyblue", "lightcoral"],
#       5     explode=[0, 0, 0.1],
#
# NameError: name 'plt' is not defined

# %%
# Import mpl to change the plot configurations using rcParams.
import matplotlib as mpl
# Build Pie Chart
plt.subplots(figsize=(10, 6))
plt.pie(type_percents,
    labels=["Rural", "Suburban", "Urban"],
    colors=["gold", "lightskyblue", "lightcoral"],
    explode=[0, 0, 0.1],
    autopct='%1.1f%%',
    shadow=True, startangle=150)
plt.title("% of Total Fares by City Type")
# Change the default font size from 10 to 14.
mpl.rcParams['font.size'] = 14
# Save Figure
plt.savefig("analysis/Fig5.png")
# Show Figure
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2096/3063868866.py in <module>
#       2 import matplotlib as mpl
#       3 # Build Pie Chart
# ----> 4 plt.subplots(figsize=(10, 6))
#       5 plt.pie(type_percents,
#       6     labels=["Rural", "Suburban", "Urban"],
#
# NameError: name 'plt' is not defined

# %%
pyber_data_df.groupby(["type"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2096/30197.py in <module>
# ----> 1 pyber_data_df.groupby(["type"])
#
# NameError: name 'pyber_data_df' is not defined

# %%
pyber_data_df.groupby(["type"]).count()["ride_id"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2096/2956135800.py in <module>
# ----> 1 pyber_data_df.groupby(["type"]).count()["ride_id"]
#
# NameError: name 'pyber_data_df' is not defined

# %%
pyber_data_df["ride_id"].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2096/3720806148.py in <module>
# ----> 1 pyber_data_df["ride_id"].count()
#
# NameError: name 'pyber_data_df' is not defined

# %%
# Calculate the percentage of rides for each city type.
ride_percents = 100 * pyber_data_df.groupby(["type"]).count()["ride_id"] / pyber_data_df["ride_id"].count()
ride_percents
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2096/3706308481.py in <module>
#       1 # Calculate the percentage of rides for each city type.
# ----> 2 ride_percents = 100 * pyber_data_df.groupby(["type"]).count()["ride_id"] / pyber_data_df["ride_id"].count()
#       3 ride_percents
#
# NameError: name 'pyber_data_df' is not defined

# %%
# Build percentage of rides by city type pie chart.
plt.subplots(figsize=(10, 6))
plt.pie(ride_percents,
    labels=["Rural", "Suburban", "Urban"],
    colors=["gold", "lightskyblue", "lightcoral"],
    explode=[0, 0, 0.1],
    autopct='%1.1f%%',
    shadow=True, startangle=150)
plt.title("% of Total Rides by City Type")
# Change the default font size from 10 to 14.
mpl.rcParams['font.size'] = 14
# Save Figure
plt.savefig("analysis/Fig6.png")
# Show Figure
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2096/1728235290.py in <module>
#       1 # Build percentage of rides by city type pie chart.
# ----> 2 plt.subplots(figsize=(10, 6))
#       3 plt.pie(ride_percents,
#       4     labels=["Rural", "Suburban", "Urban"],
#       5     colors=["gold", "lightskyblue", "lightcoral"],
#
# NameError: name 'plt' is not defined
